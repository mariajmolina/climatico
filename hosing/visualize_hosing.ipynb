# %%
import create_hosing
import matplotlib.pyplot as plt
import xarray as xr

# %%
#mask = create_hosing.make_hosing_nc(hosing_rate=0.1, fileout='yay.nc', return_file=True)

# %%
#mask

# %%
#plt.figure(figsize=(16,10)); mask['hosing'].plot.pcolormesh()

# %%
# 0.1 Sv, 0.3 Sv, and 0.5 Sv, and 0.0 Sv.
create_hosing.make_hosing_nc(hosing_rate=0.1, fileout='/glade/scratch/molina/hosing_greenland_0.1_Sv.nc')
create_hosing.make_hosing_nc(hosing_rate=0.3, fileout='/glade/scratch/molina/hosing_greenland_0.3_Sv.nc')
create_hosing.make_hosing_nc(hosing_rate=0.5, fileout='/glade/scratch/molina/hosing_greenland_0.5_Sv.nc')
create_hosing.make_hosing_nc(hosing_rate=0.0, fileout='/glade/scratch/molina/hosing_greenland_0.0_Sv.nc')

# %%
ds = xr.open_dataset('/glade/scratch/molina/hosing_greenland_0.5_Sv.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (nlat: 384, nlon: 320)
# Coordinates:
#     DXT      (nlat, nlon) float64 ...
#     DYT      (nlat, nlon) float64 ...
#     TLAT     (nlat, nlon) float64 ...
#     TLONG    (nlat, nlon) float64 ...
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     hosing   (nlat, nlon) float64 ...
# Attributes:
#     Author:             Maria J. Molina for Aixue Hu
#     File:               Greenland coast hosing
#     Hosing rate:        0.5
#     Original pop mesh:  /glade/scratch/ahu/archive/b.e22.B1850LENS.hosingCoas...
#     Hosing flux units:  kg/m2/s

# %%
plt.figure(figsize=(16,10)); ds['hosing'].plot.pcolormesh()
