# %% [markdown]
# ### First step in isotherm calculation
#
# This notebook to create smaller temporary files for isotherm calculation (using pyferret).
#
# Use scratch space to create ``temp`` directories.

# %%
import xarray as xr
import numpy as np
from datetime import timedelta

# %%
from config import directory_figs, directory_data

# %%
exp = 'FWAtSalG02Sv'

file_list =  [f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.000101-005012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.005101-010012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.010101-015012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.015101-020012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.020101-025012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.025101-030012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.030101-035012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.035101-040012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.040101-045012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.045101-050012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.050101-055012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.055101-060012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.060101-065012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.065101-070012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.070101-075012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.075101-080312.nc']

num = 0

for filename in file_list:

    ds = xr.open_dataset(f'{directory_data}{filename}')
    # fix time coord
    ds = ds.assign_coords(time=ds.coords['time'] - timedelta(days=17))

    one = np.arange(0, ((ds.time.shape[0]/12)*12), 12, dtype=int)
    two = np.arange(12, ((ds.time.shape[0]/12)*12)+1, 12, dtype=int)

    for i, j in zip(one, two):
        
        ds.isel(time=slice(i, j)).to_netcdf(f'{directory_data}temp_{exp}/file_{num}.nc')
        num += 1

# %%
exp = 'FWAtSalG04Sv'

file_list =  [f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.000101-005012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.005101-010012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.010101-015012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.015101-020012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.020101-025012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.025101-030012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.030101-035012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.035101-040012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.040101-045012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.045101-050012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.050101-055012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.055101-060012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.060101-065012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.065101-070012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.070101-075012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.075101-080012.nc']

num = 0

for filename in file_list:

    ds = xr.open_dataset(f'{directory_data}{filename}')
    # fix time coord
    ds = ds.assign_coords(time=ds.coords['time'] - timedelta(days=17))

    one = np.arange(0, ((ds.time.shape[0]/12)*12), 12, dtype=int)
    two = np.arange(12, ((ds.time.shape[0]/12)*12)+1, 12, dtype=int)

    for i, j in zip(one, two):
        
        ds.isel(time=slice(i, j)).to_netcdf(f'{directory_data}temp_{exp}/file_{num}.nc')
        num += 1

# %%
exp = 'FWAtSalP02Sv'

file_list =  [f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.000101-005012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.005101-010012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.010101-015012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.015101-020012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.020101-025012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.025101-030012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.030101-035012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.035101-040012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.040101-045012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.045101-050012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.050101-055012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.055101-060012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.060101-065012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.065101-070012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.070101-075012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.075101-080012.nc']

num = 0

for filename in file_list:

    ds = xr.open_dataset(f'{directory_data}{filename}')
    # fix time coord
    ds = ds.assign_coords(time=ds.coords['time'] - timedelta(days=17))

    one = np.arange(0, ((ds.time.shape[0]/12)*12), 12, dtype=int)
    two = np.arange(12, ((ds.time.shape[0]/12)*12)+1, 12, dtype=int)

    for i, j in zip(one, two):
        
        ds.isel(time=slice(i, j)).to_netcdf(f'{directory_data}temp_{exp}/file_{num}.nc')
        num += 1

# %%
exp = 'FWAtSalP04Sv'

file_list =  [f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.000101-005012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.005101-010012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.010101-015012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.015101-020012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.020101-025012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.025101-030012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.030101-035012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.035101-040012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.040101-045012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.045101-050012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.050101-055012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.055101-060012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.060101-065012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.065101-070012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.070101-075012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.075101-080012.nc']

num = 0

for filename in file_list:

    ds = xr.open_dataset(f'{directory_data}{filename}')
    # fix time coord
    ds = ds.assign_coords(time=ds.coords['time'] - timedelta(days=17))

    one = np.arange(0, ((ds.time.shape[0]/12)*12), 12, dtype=int)
    two = np.arange(12, ((ds.time.shape[0]/12)*12)+1, 12, dtype=int)

    for i, j in zip(one, two):
        
        ds.isel(time=slice(i, j)).to_netcdf(f'{directory_data}temp_{exp}/file_{num}.nc')
        num += 1

# %%
exp = 'FWPaSalP04Sv'

file_list =  [f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.000101-005012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.005101-010012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.010101-015012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.015101-020012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.020101-025012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.025101-030012.nc',
              f'b.e11.B1850LENS.f09_g16.{exp}.pop.h.TEMP.030101-035012.nc']

num = 0

for filename in file_list:

    ds = xr.open_dataset(f'{directory_data}{filename}')
    # fix time coord
    ds = ds.assign_coords(time=ds.coords['time'] - timedelta(days=17))

    one = np.arange(0, ((ds.time.shape[0]/12)*12), 12, dtype=int)
    two = np.arange(12, ((ds.time.shape[0]/12)*12)+1, 12, dtype=int)

    for i, j in zip(one, two):
        
        ds.isel(time=slice(i, j)).to_netcdf(f'{directory_data}temp_{exp}/file_{num}.nc')
        num += 1

# %%
exp = '005'    ### create new list for control

file_list =  [f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.040001-049912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.050001-059912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.060001-069912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.070001-079912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.080001-089912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.090001-099912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.100001-109912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.110001-119912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.120001-129912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.130001-139912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.140001-149912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.150001-159912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.160001-169912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.170001-179912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.180001-189912.nc',
              f'b.e11.B1850C5CN.f09_g16.{exp}.pop.h.TEMP.190001-199912.nc']

num = 0

for filename in file_list:

    ds = xr.open_dataset(f'{directory_data}{filename}')
    # fix time coord
    ds = ds.assign_coords(time=ds.coords['time'] - timedelta(days=17))

    one = np.arange(0, ((ds.time.shape[0]/12)*12), 12, dtype=int)
    two = np.arange(12, ((ds.time.shape[0]/12)*12)+1, 12, dtype=int)

    for i, j in zip(one, two):
        
        ds.isel(time=slice(i, j)).to_netcdf(f'{directory_data}temp_{exp}/file_{num}.nc')
        num += 1
